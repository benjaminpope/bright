# %% [markdown]
# ## Inspect - look at raw data to determine splits

# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy.table import Table

% matplotlib inline

import matplotlib as mpl

print mpl.style.available
mpl.style.use('seaborn-colorblind')
mpl.rcParams['figure.figsize']=(8.0,6.0)    #(6.0,4.0)
mpl.rcParams['font.size']=18               #10 
mpl.rcParams['savefig.dpi']= 200             #72 
mpl.rcParams['axes.labelsize'] = 16
mpl.rcParams['axes.labelsize'] = 16
mpl.rcParams['xtick.labelsize'] = 12
mpl.rcParams['ytick.labelsize'] = 12
# Out:
# [u'seaborn-darkgrid', u'seaborn-notebook', u'classic', u'seaborn-ticks', u'grayscale', u'bmh', u'seaborn-talk', u'dark_background', u'ggplot', u'fivethirtyeight', u'_classic_test', u'seaborn-colorblind', u'seaborn-deep', u'seaborn-whitegrid', u'seaborn-bright', u'seaborn-poster', u'seaborn-muted', u'seaborn-paper', u'seaborn-white', u'seaborn-pastel', u'seaborn-dark', u'seaborn', u'seaborn-dark-palette']

# %%
epic = 248557606
campaign = 14
fname = 'ktwo%d-c%d_llc.fits'% (epic,campaign)

# %%
data = Table.read(fname)

# %%
time = data['TIME']
x, y = data['POS_CORR1'], data['POS_CORR2']
m = np.abs(x)<10
x, y, time = x[m], y[m], time[m]
# Out:
# /Users/benjaminpope/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:3: RuntimeWarning: invalid value encountered in less
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# plt.plot(time,x,'.')
plt.plot(time,y,'.')
plt.axvline(3085)
plt.axvline(3124)
